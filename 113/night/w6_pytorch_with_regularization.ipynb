# %% [markdown]
# # **Regularisation in PyTorch - Part 2**
# ### **Now we use a few Regularisation methods on our Fashion-MNIST CNN**
#
#
# 1. Import PyTorch libraries, define our Transformers, Load our dataset and Visualize our images.
# 2. Build a Simple CNN with the following **Regularisation** methods:
#   - L2 Regularisation
#   - Data Augmentation
#   - Dropout
#   - BatchNorm
# 3. Training our CNN with Regularisation

# %% [markdown]
# # **1. Import PyTorch libraries, Define Transfomers and Load & Visualise Dataset**

# %%
# Import PyTorch
import torch
import PIL
import numpy as np

# We use torchvision to get our dataset and useful image transformations
import torchvision
import torchvision.transforms as transforms

# Import PyTorch's optimization libary and nn
# nn is used as the basic building block for our Network graphs
import torch.optim as optim
import torch.nn as nn

# Are we using our GPU?
print("GPU available: {}".format(torch.cuda.is_available()))
# Out:
# GPU available: True

# %%
device = 'cuda' #'cpu' if no GPU available

# %% [markdown]
# # **2. Building a CNN with Regulisation**
# ## **Implementing Data Augmentation**
#
# #### **Understanding What Our Transforms Do**
#
# 1. Our Transforms are applied to an image or batch of images everytime it's loaded.
# 2. These new images aren't saved, they're generated or 'altered' everytime a batch is loaded
#
# #### **NOTE**
#
# We don't apply the same augmentations to our Test or Validation Datasets. Therefore, we keep separate transformation functions (see below) for our Train and Validation/Test data.

# %%
data_transforms = {
    'train': transforms.Compose([
        # Note these are executed in the order they are called here
        # Some of these transforms return a color image, hence why we need to convert
        # the image back to grayscale
        transforms.RandomAffine(degrees = 10, translate = (0.05,0.05), shear = 5),
        transforms.ColorJitter(hue = .05, saturation = .05),
        transforms.RandomHorizontalFlip(),
        transforms.Grayscale(num_output_channels = 1),
        transforms.ToTensor(),
        transforms.Normalize((0.5, ), (0.5, )),
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, ), (0.5, ))
    ])
}

# %% [markdown]
# ### **Fetch and Create our Data Loaders**

# %%
# Load our Train Data and specify what transform to use when loading
trainset = torchvision.datasets.FashionMNIST(root='./data', train=True,
                                        download=True, transform=data_transforms['train'])

# Load our Test Data and specify what transform to use when loading
testset = torchvision.datasets.FashionMNIST(root='./data', train=False,
                                       download=True, transform=data_transforms['val'])

# Prepare train and test loader
trainloader = torch.utils.data.DataLoader(trainset, batch_size=32,
                                          shuffle=True)

testloader = torch.utils.data.DataLoader(testset, batch_size=32,
                                         shuffle=False)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:05<00:00, 4415349.20it/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 204235.14it/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:01<00:00, 3725844.24it/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<00:00, 21168899.01it/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw

# %% [markdown]
# ### **Adding Dropout**
#
# In Convolutional Neural Networks Dropout is commonly added after CONV-RELU Layers.
#
# E.g. CONV->RELU->**DROPOUT**
#
# #### **Dropout Recommendations**
#
# In CNN's values of 0.1 to 0.3 have been found to work well.
#
# ### **Adding BatchNorm**
#
# In CNNs **BatchNorm** is best used between the Conv Layer and the activation function layer (ReLU)
# When used with Dropout, the recommended order is:
#
# CONV_1 -> **BatchNorm** -> ReLU -> Dropout - CONV_2
#
# **NOTE** BatchNorm's input arguement is the **output** size of the previous layer.

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3)
        # Adding BatchNorm, using 32 as the input since 32 was the output of our first Conv layer
        self.conv1_bn = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, 3)
        # Adding BatchNorm, using 64 as the input since 64 was the output of our first Conv layer
        self.conv2_bn = nn.BatchNorm2d(64)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 12 * 12, 128)
        self.fc2 = nn.Linear(128, 10)
        # Defining our dropout function with a rate of 0.2
        # We can apply this after any layer, but it's best suited after ReLU
        self.dropOut = nn.Dropout(0.2)

    def forward(self, x):
        x = F.relu(self.conv1_bn(self.conv1(x)))
        x = self.dropOut(x)
        x = self.dropOut(F.relu(self.conv2_bn(self.conv2(x))))

        x = self.pool(x)
        x = x.view(-1, 64 * 12 * 12)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x


net = Net()
net.to(device)
# Out:
# Net(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv1_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv2_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=9216, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
#   (dropOut): Dropout(p=0.2, inplace=False)
# )

# %% [markdown]
# ### **Adding L2 Regularisation**
#
#
# L2 regularisation on the parameters/weights of the model is directly included in most optimizers, including optim.SGD.
#
# It can be controlled with the **weight_decay** parameter as can be seen in the [SGD documentation](http://pytorch.org/docs/optim.html#torch.optim.SGD).
#
# ```weight_decay``` (**float**, optional) – weight decay *(L2 penalty) (default: 0)*
#
# **Good L2 Values range from 0.1 to 0.0001**
#
# **NOTE:**
#
#  L1 regularization is not included by default in the optimizers, but could be added by including an extra loss nn.L1Loss in the weights of the model.

# %%
# We import our optimizer function
import torch.optim as optim

# We use Cross Entropy Loss as our loss function
criterion = nn.CrossEntropyLoss()

# For our gradient descent algorthim or Optimizer
# We use Stochastic Gradient Descent (SGD) with a learning rate of 0.001
# We set the momentum to be 0.9
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9, weight_decay = 0.001)

# %% [markdown]
# # **3. Training Our Model Using Regulisation Methods - Data Augmentation, Dropout, BatchNorm & L2 Regularisation**

# %%
# We loop over the traing dataset multiple times (each time is called an epoch)
epochs = 15

# Create some empty arrays to store logs
epoch_log = []
loss_log = []
accuracy_log = []

# Iterate for a specified number of epochs
for epoch in range(epochs):
    print(f'Starting Epoch: {epoch+1}...')

    # We keep adding or accumulating our loss after each mini-batch in running_loss
    running_loss = 0.0

    # We iterate through our trainloader iterator
    # Each cycle is a minibatch
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # Move our data to GPU
        inputs = inputs.to(device)
        labels = labels.to(device)

        # Clear the gradients before training by setting to zero
        # Required for a fresh start
        optimizer.zero_grad()

        # Forward -> backprop + optimize
        outputs = net(inputs) # Forward Propagation
        loss = criterion(outputs, labels) # Get Loss (quantify the difference between the results and predictions)
        loss.backward() # Back propagate to obtain the new gradients for all nodes
        optimizer.step() # Update the gradients/weights

        # Print Training statistics - Epoch/Iterations/Loss/Accurachy
        running_loss += loss.item()
        if i % 100 == 99:    # show our loss every 50 mini-batches
            correct = 0 # Initialize our variable to hold the count for the correct predictions
            total = 0 # Initialize our variable to hold the count of the number of labels iterated

            # We don't need gradients for validation, so wrap in
            # no_grad to save memory
            with torch.no_grad():
                # Iterate through the testloader iterator
                for data in testloader:
                    images, labels = data
                    # Move our data to GPU
                    images = images.to(device)
                    labels = labels.to(device)

                    # Foward propagate our test data batch through our model
                    outputs = net(images)

                     # Get predictions from the maximum value
                    _, predicted = torch.max(outputs.data, 1)
                    # Keep adding the label size or length to the total variable
                    total += labels.size(0)
                    # Keep a running total of the number of predictions predicted correctly
                    correct += (predicted == labels).sum().item()

                accuracy = 100 * correct / total
                epoch_num = epoch + 1
                actual_loss = running_loss / 50
                print(f'Epoch: {epoch_num}, Mini-Batches Completed: {(i+1)}, Loss: {actual_loss:.3f}, Test Accuracy = {accuracy:.3f}%')
                running_loss = 0.0

    # Store training stats after each epoch
    epoch_log.append(epoch_num)
    loss_log.append(actual_loss)
    accuracy_log.append(accuracy)

print('Finished Training')
# Out:
# Starting Epoch: 1...
# Epoch: 1, Mini-Batches Completed: 100, Loss: 2.437, Test Accuracy = 73.790%
# Epoch: 1, Mini-Batches Completed: 200, Loss: 1.521, Test Accuracy = 77.080%
# Epoch: 1, Mini-Batches Completed: 300, Loss: 1.368, Test Accuracy = 78.260%
# Epoch: 1, Mini-Batches Completed: 400, Loss: 1.252, Test Accuracy = 79.800%
# Epoch: 1, Mini-Batches Completed: 500, Loss: 1.267, Test Accuracy = 78.800%
# Epoch: 1, Mini-Batches Completed: 600, Loss: 1.159, Test Accuracy = 81.820%
# Epoch: 1, Mini-Batches Completed: 700, Loss: 1.145, Test Accuracy = 82.130%
# Epoch: 1, Mini-Batches Completed: 800, Loss: 1.052, Test Accuracy = 80.950%
# Epoch: 1, Mini-Batches Completed: 900, Loss: 1.030, Test Accuracy = 81.810%
# Epoch: 1, Mini-Batches Completed: 1000, Loss: 1.064, Test Accuracy = 82.010%
# Epoch: 1, Mini-Batches Completed: 1100, Loss: 0.998, Test Accuracy = 83.580%
# Epoch: 1, Mini-Batches Completed: 1200, Loss: 1.087, Test Accuracy = 83.860%
# Epoch: 1, Mini-Batches Completed: 1300, Loss: 0.932, Test Accuracy = 84.080%
# Epoch: 1, Mini-Batches Completed: 1400, Loss: 0.982, Test Accuracy = 84.270%
# Epoch: 1, Mini-Batches Completed: 1500, Loss: 0.946, Test Accuracy = 85.410%
# Epoch: 1, Mini-Batches Completed: 1600, Loss: 0.946, Test Accuracy = 85.190%
# Epoch: 1, Mini-Batches Completed: 1700, Loss: 0.994, Test Accuracy = 85.090%
# Epoch: 1, Mini-Batches Completed: 1800, Loss: 0.925, Test Accuracy = 83.550%
# Starting Epoch: 2...
# Epoch: 2, Mini-Batches Completed: 100, Loss: 0.931, Test Accuracy = 85.420%
# Epoch: 2, Mini-Batches Completed: 200, Loss: 0.901, Test Accuracy = 85.990%
# Epoch: 2, Mini-Batches Completed: 300, Loss: 0.841, Test Accuracy = 85.220%
# Epoch: 2, Mini-Batches Completed: 400, Loss: 0.882, Test Accuracy = 86.190%
# Epoch: 2, Mini-Batches Completed: 500, Loss: 0.884, Test Accuracy = 85.880%
# Epoch: 2, Mini-Batches Completed: 600, Loss: 0.853, Test Accuracy = 86.260%
# Epoch: 2, Mini-Batches Completed: 700, Loss: 0.849, Test Accuracy = 85.480%
# Epoch: 2, Mini-Batches Completed: 800, Loss: 0.870, Test Accuracy = 85.830%
# Epoch: 2, Mini-Batches Completed: 900, Loss: 0.911, Test Accuracy = 85.850%
# Epoch: 2, Mini-Batches Completed: 1000, Loss: 0.891, Test Accuracy = 85.950%
# Epoch: 2, Mini-Batches Completed: 1100, Loss: 0.817, Test Accuracy = 86.300%
# Epoch: 2, Mini-Batches Completed: 1200, Loss: 0.759, Test Accuracy = 85.020%
# Epoch: 2, Mini-Batches Completed: 1300, Loss: 0.885, Test Accuracy = 87.060%
# Epoch: 2, Mini-Batches Completed: 1400, Loss: 0.869, Test Accuracy = 86.180%
# Epoch: 2, Mini-Batches Completed: 1500, Loss: 0.816, Test Accuracy = 87.130%
# Epoch: 2, Mini-Batches Completed: 1600, Loss: 0.823, Test Accuracy = 87.010%
# Epoch: 2, Mini-Batches Completed: 1700, Loss: 0.787, Test Accuracy = 86.160%
# Epoch: 2, Mini-Batches Completed: 1800, Loss: 0.812, Test Accuracy = 87.010%
# Starting Epoch: 3...
# Epoch: 3, Mini-Batches Completed: 100, Loss: 0.821, Test Accuracy = 87.400%
# Epoch: 3, Mini-Batches Completed: 200, Loss: 0.754, Test Accuracy = 87.300%
# Epoch: 3, Mini-Batches Completed: 300, Loss: 0.802, Test Accuracy = 86.660%
# Epoch: 3, Mini-Batches Completed: 400, Loss: 0.758, Test Accuracy = 87.320%
# Epoch: 3, Mini-Batches Completed: 500, Loss: 0.774, Test Accuracy = 88.200%
# Epoch: 3, Mini-Batches Completed: 600, Loss: 0.756, Test Accuracy = 87.240%
# Epoch: 3, Mini-Batches Completed: 700, Loss: 0.761, Test Accuracy = 87.720%
# Epoch: 3, Mini-Batches Completed: 800, Loss: 0.752, Test Accuracy = 87.660%
# Epoch: 3, Mini-Batches Completed: 900, Loss: 0.764, Test Accuracy = 87.280%
# Epoch: 3, Mini-Batches Completed: 1000, Loss: 0.751, Test Accuracy = 87.260%
# Epoch: 3, Mini-Batches Completed: 1100, Loss: 0.779, Test Accuracy = 87.260%
# Epoch: 3, Mini-Batches Completed: 1200, Loss: 0.821, Test Accuracy = 87.140%
# Epoch: 3, Mini-Batches Completed: 1300, Loss: 0.776, Test Accuracy = 87.430%
# Epoch: 3, Mini-Batches Completed: 1400, Loss: 0.761, Test Accuracy = 87.470%
# Epoch: 3, Mini-Batches Completed: 1500, Loss: 0.767, Test Accuracy = 88.100%
# Epoch: 3, Mini-Batches Completed: 1600, Loss: 0.742, Test Accuracy = 87.560%
# Epoch: 3, Mini-Batches Completed: 1700, Loss: 0.720, Test Accuracy = 88.440%
# Epoch: 3, Mini-Batches Completed: 1800, Loss: 0.750, Test Accuracy = 88.490%
# Starting Epoch: 4...
# Epoch: 4, Mini-Batches Completed: 100, Loss: 0.812, Test Accuracy = 88.360%
# Epoch: 4, Mini-Batches Completed: 200, Loss: 0.695, Test Accuracy = 88.530%
# Epoch: 4, Mini-Batches Completed: 300, Loss: 0.720, Test Accuracy = 88.260%
# Epoch: 4, Mini-Batches Completed: 400, Loss: 0.692, Test Accuracy = 88.180%
# Epoch: 4, Mini-Batches Completed: 500, Loss: 0.735, Test Accuracy = 88.260%
# Epoch: 4, Mini-Batches Completed: 600, Loss: 0.710, Test Accuracy = 87.610%
# Epoch: 4, Mini-Batches Completed: 700, Loss: 0.764, Test Accuracy = 87.840%
# Epoch: 4, Mini-Batches Completed: 800, Loss: 0.696, Test Accuracy = 88.640%
# Epoch: 4, Mini-Batches Completed: 900, Loss: 0.723, Test Accuracy = 88.620%
# Epoch: 4, Mini-Batches Completed: 1000, Loss: 0.709, Test Accuracy = 88.780%
# Epoch: 4, Mini-Batches Completed: 1100, Loss: 0.751, Test Accuracy = 88.370%
# Epoch: 4, Mini-Batches Completed: 1200, Loss: 0.737, Test Accuracy = 88.300%
# Epoch: 4, Mini-Batches Completed: 1300, Loss: 0.725, Test Accuracy = 88.460%
# Epoch: 4, Mini-Batches Completed: 1400, Loss: 0.708, Test Accuracy = 88.720%
# Epoch: 4, Mini-Batches Completed: 1500, Loss: 0.677, Test Accuracy = 88.150%
# Epoch: 4, Mini-Batches Completed: 1600, Loss: 0.719, Test Accuracy = 88.650%
# Epoch: 4, Mini-Batches Completed: 1700, Loss: 0.705, Test Accuracy = 87.530%
# Epoch: 4, Mini-Batches Completed: 1800, Loss: 0.760, Test Accuracy = 88.860%
# Starting Epoch: 5...
# Epoch: 5, Mini-Batches Completed: 100, Loss: 0.670, Test Accuracy = 88.650%
# Epoch: 5, Mini-Batches Completed: 200, Loss: 0.711, Test Accuracy = 87.730%
# Epoch: 5, Mini-Batches Completed: 300, Loss: 0.733, Test Accuracy = 88.160%
# Epoch: 5, Mini-Batches Completed: 400, Loss: 0.695, Test Accuracy = 88.440%
# Epoch: 5, Mini-Batches Completed: 500, Loss: 0.717, Test Accuracy = 88.680%
# Epoch: 5, Mini-Batches Completed: 600, Loss: 0.703, Test Accuracy = 88.900%
# Epoch: 5, Mini-Batches Completed: 700, Loss: 0.673, Test Accuracy = 89.170%
# Epoch: 5, Mini-Batches Completed: 800, Loss: 0.681, Test Accuracy = 89.040%
# Epoch: 5, Mini-Batches Completed: 900, Loss: 0.680, Test Accuracy = 89.190%
# Epoch: 5, Mini-Batches Completed: 1000, Loss: 0.660, Test Accuracy = 88.490%
# Epoch: 5, Mini-Batches Completed: 1100, Loss: 0.676, Test Accuracy = 88.260%
# Epoch: 5, Mini-Batches Completed: 1200, Loss: 0.672, Test Accuracy = 89.090%
# Epoch: 5, Mini-Batches Completed: 1300, Loss: 0.712, Test Accuracy = 88.890%
# Epoch: 5, Mini-Batches Completed: 1400, Loss: 0.686, Test Accuracy = 88.000%
# Epoch: 5, Mini-Batches Completed: 1500, Loss: 0.649, Test Accuracy = 88.840%
# Epoch: 5, Mini-Batches Completed: 1600, Loss: 0.657, Test Accuracy = 89.040%
# Epoch: 5, Mini-Batches Completed: 1700, Loss: 0.648, Test Accuracy = 88.760%
# Epoch: 5, Mini-Batches Completed: 1800, Loss: 0.634, Test Accuracy = 88.430%
# Starting Epoch: 6...
# Epoch: 6, Mini-Batches Completed: 100, Loss: 0.675, Test Accuracy = 88.480%
# Epoch: 6, Mini-Batches Completed: 200, Loss: 0.643, Test Accuracy = 88.650%
# Epoch: 6, Mini-Batches Completed: 300, Loss: 0.658, Test Accuracy = 88.190%
# Epoch: 6, Mini-Batches Completed: 400, Loss: 0.618, Test Accuracy = 89.480%
# Epoch: 6, Mini-Batches Completed: 500, Loss: 0.652, Test Accuracy = 88.400%
# Epoch: 6, Mini-Batches Completed: 600, Loss: 0.706, Test Accuracy = 89.070%
# Epoch: 6, Mini-Batches Completed: 700, Loss: 0.659, Test Accuracy = 89.190%
# Epoch: 6, Mini-Batches Completed: 800, Loss: 0.681, Test Accuracy = 88.330%
# Epoch: 6, Mini-Batches Completed: 900, Loss: 0.610, Test Accuracy = 88.490%
# Epoch: 6, Mini-Batches Completed: 1000, Loss: 0.669, Test Accuracy = 88.930%
# Epoch: 6, Mini-Batches Completed: 1100, Loss: 0.643, Test Accuracy = 89.320%
# Epoch: 6, Mini-Batches Completed: 1200, Loss: 0.631, Test Accuracy = 89.320%
# Epoch: 6, Mini-Batches Completed: 1300, Loss: 0.680, Test Accuracy = 88.830%
# Epoch: 6, Mini-Batches Completed: 1400, Loss: 0.629, Test Accuracy = 89.540%
# Epoch: 6, Mini-Batches Completed: 1500, Loss: 0.685, Test Accuracy = 88.990%
# Epoch: 6, Mini-Batches Completed: 1600, Loss: 0.678, Test Accuracy = 89.260%
# Epoch: 6, Mini-Batches Completed: 1700, Loss: 0.599, Test Accuracy = 89.730%
# Epoch: 6, Mini-Batches Completed: 1800, Loss: 0.622, Test Accuracy = 89.050%
# Starting Epoch: 7...
# Epoch: 7, Mini-Batches Completed: 100, Loss: 0.619, Test Accuracy = 88.260%
# Epoch: 7, Mini-Batches Completed: 200, Loss: 0.619, Test Accuracy = 88.860%
# Epoch: 7, Mini-Batches Completed: 300, Loss: 0.578, Test Accuracy = 88.940%
# Epoch: 7, Mini-Batches Completed: 400, Loss: 0.633, Test Accuracy = 89.310%
# Epoch: 7, Mini-Batches Completed: 500, Loss: 0.610, Test Accuracy = 89.470%
# Epoch: 7, Mini-Batches Completed: 600, Loss: 0.626, Test Accuracy = 89.910%
# Epoch: 7, Mini-Batches Completed: 700, Loss: 0.623, Test Accuracy = 89.210%
# Epoch: 7, Mini-Batches Completed: 800, Loss: 0.588, Test Accuracy = 89.400%
# Epoch: 7, Mini-Batches Completed: 900, Loss: 0.617, Test Accuracy = 88.960%
# Epoch: 7, Mini-Batches Completed: 1000, Loss: 0.637, Test Accuracy = 88.950%
# Epoch: 7, Mini-Batches Completed: 1100, Loss: 0.691, Test Accuracy = 89.450%
# Epoch: 7, Mini-Batches Completed: 1200, Loss: 0.664, Test Accuracy = 89.640%
# Epoch: 7, Mini-Batches Completed: 1300, Loss: 0.671, Test Accuracy = 89.810%
# Epoch: 7, Mini-Batches Completed: 1400, Loss: 0.578, Test Accuracy = 89.110%
# Epoch: 7, Mini-Batches Completed: 1500, Loss: 0.649, Test Accuracy = 89.820%
# Epoch: 7, Mini-Batches Completed: 1600, Loss: 0.632, Test Accuracy = 89.520%
# Epoch: 7, Mini-Batches Completed: 1700, Loss: 0.638, Test Accuracy = 88.870%
# Epoch: 7, Mini-Batches Completed: 1800, Loss: 0.622, Test Accuracy = 89.910%
# Starting Epoch: 8...
# Epoch: 8, Mini-Batches Completed: 100, Loss: 0.595, Test Accuracy = 89.800%
# Epoch: 8, Mini-Batches Completed: 200, Loss: 0.587, Test Accuracy = 89.870%
# Epoch: 8, Mini-Batches Completed: 300, Loss: 0.599, Test Accuracy = 89.640%
# Epoch: 8, Mini-Batches Completed: 400, Loss: 0.644, Test Accuracy = 89.410%
# Epoch: 8, Mini-Batches Completed: 500, Loss: 0.584, Test Accuracy = 89.630%
# Epoch: 8, Mini-Batches Completed: 600, Loss: 0.587, Test Accuracy = 89.600%
# Epoch: 8, Mini-Batches Completed: 700, Loss: 0.637, Test Accuracy = 89.970%
# Epoch: 8, Mini-Batches Completed: 800, Loss: 0.662, Test Accuracy = 89.090%
# Epoch: 8, Mini-Batches Completed: 900, Loss: 0.642, Test Accuracy = 89.760%
# Epoch: 8, Mini-Batches Completed: 1000, Loss: 0.598, Test Accuracy = 89.570%
# Epoch: 8, Mini-Batches Completed: 1100, Loss: 0.604, Test Accuracy = 89.410%
# Epoch: 8, Mini-Batches Completed: 1200, Loss: 0.653, Test Accuracy = 89.670%
# Epoch: 8, Mini-Batches Completed: 1300, Loss: 0.595, Test Accuracy = 89.270%
# Epoch: 8, Mini-Batches Completed: 1400, Loss: 0.653, Test Accuracy = 90.290%
# Epoch: 8, Mini-Batches Completed: 1500, Loss: 0.610, Test Accuracy = 89.370%
# Epoch: 8, Mini-Batches Completed: 1600, Loss: 0.601, Test Accuracy = 90.210%
# Epoch: 8, Mini-Batches Completed: 1700, Loss: 0.639, Test Accuracy = 90.010%
# Epoch: 8, Mini-Batches Completed: 1800, Loss: 0.582, Test Accuracy = 89.910%
# Starting Epoch: 9...
# Epoch: 9, Mini-Batches Completed: 100, Loss: 0.606, Test Accuracy = 89.790%
# Epoch: 9, Mini-Batches Completed: 200, Loss: 0.573, Test Accuracy = 89.640%
# Epoch: 9, Mini-Batches Completed: 300, Loss: 0.572, Test Accuracy = 89.080%
# Epoch: 9, Mini-Batches Completed: 400, Loss: 0.595, Test Accuracy = 89.650%
# Epoch: 9, Mini-Batches Completed: 500, Loss: 0.604, Test Accuracy = 88.960%
# Epoch: 9, Mini-Batches Completed: 600, Loss: 0.571, Test Accuracy = 89.700%
# Epoch: 9, Mini-Batches Completed: 700, Loss: 0.598, Test Accuracy = 89.990%
# Epoch: 9, Mini-Batches Completed: 800, Loss: 0.634, Test Accuracy = 89.490%
# Epoch: 9, Mini-Batches Completed: 900, Loss: 0.568, Test Accuracy = 90.100%
# Epoch: 9, Mini-Batches Completed: 1000, Loss: 0.602, Test Accuracy = 89.160%
# Epoch: 9, Mini-Batches Completed: 1100, Loss: 0.593, Test Accuracy = 89.340%
# Epoch: 9, Mini-Batches Completed: 1200, Loss: 0.605, Test Accuracy = 89.820%
# Epoch: 9, Mini-Batches Completed: 1300, Loss: 0.625, Test Accuracy = 89.590%
# Epoch: 9, Mini-Batches Completed: 1400, Loss: 0.589, Test Accuracy = 89.870%
# Epoch: 9, Mini-Batches Completed: 1500, Loss: 0.600, Test Accuracy = 89.970%
# Epoch: 9, Mini-Batches Completed: 1600, Loss: 0.611, Test Accuracy = 89.870%
# Epoch: 9, Mini-Batches Completed: 1700, Loss: 0.591, Test Accuracy = 90.080%
# Epoch: 9, Mini-Batches Completed: 1800, Loss: 0.595, Test Accuracy = 89.960%
# Starting Epoch: 10...
# Epoch: 10, Mini-Batches Completed: 100, Loss: 0.566, Test Accuracy = 89.880%
# Epoch: 10, Mini-Batches Completed: 200, Loss: 0.553, Test Accuracy = 89.740%
# Epoch: 10, Mini-Batches Completed: 300, Loss: 0.578, Test Accuracy = 90.160%
# Epoch: 10, Mini-Batches Completed: 400, Loss: 0.622, Test Accuracy = 90.100%
# Epoch: 10, Mini-Batches Completed: 500, Loss: 0.582, Test Accuracy = 90.370%
# Epoch: 10, Mini-Batches Completed: 600, Loss: 0.623, Test Accuracy = 89.550%
# Epoch: 10, Mini-Batches Completed: 700, Loss: 0.567, Test Accuracy = 89.990%
# Epoch: 10, Mini-Batches Completed: 800, Loss: 0.575, Test Accuracy = 90.180%
# Epoch: 10, Mini-Batches Completed: 900, Loss: 0.558, Test Accuracy = 90.500%
# Epoch: 10, Mini-Batches Completed: 1000, Loss: 0.584, Test Accuracy = 90.260%
# Epoch: 10, Mini-Batches Completed: 1100, Loss: 0.561, Test Accuracy = 90.130%
# Epoch: 10, Mini-Batches Completed: 1200, Loss: 0.615, Test Accuracy = 89.950%
# Epoch: 10, Mini-Batches Completed: 1300, Loss: 0.588, Test Accuracy = 89.770%
# Epoch: 10, Mini-Batches Completed: 1400, Loss: 0.603, Test Accuracy = 89.900%
# Epoch: 10, Mini-Batches Completed: 1500, Loss: 0.580, Test Accuracy = 89.870%
# Epoch: 10, Mini-Batches Completed: 1600, Loss: 0.595, Test Accuracy = 90.080%
# Epoch: 10, Mini-Batches Completed: 1700, Loss: 0.573, Test Accuracy = 90.150%
# Epoch: 10, Mini-Batches Completed: 1800, Loss: 0.589, Test Accuracy = 89.850%
# Starting Epoch: 11...
# Epoch: 11, Mini-Batches Completed: 100, Loss: 0.566, Test Accuracy = 90.170%
# Epoch: 11, Mini-Batches Completed: 200, Loss: 0.589, Test Accuracy = 89.950%
# Epoch: 11, Mini-Batches Completed: 300, Loss: 0.592, Test Accuracy = 88.760%
# Epoch: 11, Mini-Batches Completed: 400, Loss: 0.588, Test Accuracy = 90.200%
# Epoch: 11, Mini-Batches Completed: 500, Loss: 0.571, Test Accuracy = 90.280%
# Epoch: 11, Mini-Batches Completed: 600, Loss: 0.605, Test Accuracy = 90.130%
# Epoch: 11, Mini-Batches Completed: 700, Loss: 0.558, Test Accuracy = 89.630%
# Epoch: 11, Mini-Batches Completed: 800, Loss: 0.525, Test Accuracy = 89.390%
# Epoch: 11, Mini-Batches Completed: 900, Loss: 0.531, Test Accuracy = 90.010%
# Epoch: 11, Mini-Batches Completed: 1000, Loss: 0.570, Test Accuracy = 90.520%
# Epoch: 11, Mini-Batches Completed: 1100, Loss: 0.513, Test Accuracy = 89.240%
# Epoch: 11, Mini-Batches Completed: 1200, Loss: 0.567, Test Accuracy = 90.200%
# Epoch: 11, Mini-Batches Completed: 1300, Loss: 0.572, Test Accuracy = 90.350%
# Epoch: 11, Mini-Batches Completed: 1400, Loss: 0.580, Test Accuracy = 90.590%
# Epoch: 11, Mini-Batches Completed: 1500, Loss: 0.602, Test Accuracy = 90.320%
# Epoch: 11, Mini-Batches Completed: 1600, Loss: 0.591, Test Accuracy = 89.850%
# Epoch: 11, Mini-Batches Completed: 1700, Loss: 0.590, Test Accuracy = 90.450%
# Epoch: 11, Mini-Batches Completed: 1800, Loss: 0.556, Test Accuracy = 90.070%
# Starting Epoch: 12...
# Epoch: 12, Mini-Batches Completed: 100, Loss: 0.559, Test Accuracy = 90.330%
# Epoch: 12, Mini-Batches Completed: 200, Loss: 0.585, Test Accuracy = 89.740%
# Epoch: 12, Mini-Batches Completed: 300, Loss: 0.569, Test Accuracy = 90.110%
# Epoch: 12, Mini-Batches Completed: 400, Loss: 0.565, Test Accuracy = 90.140%
# Epoch: 12, Mini-Batches Completed: 500, Loss: 0.530, Test Accuracy = 90.430%
# Epoch: 12, Mini-Batches Completed: 600, Loss: 0.567, Test Accuracy = 90.590%
# Epoch: 12, Mini-Batches Completed: 700, Loss: 0.541, Test Accuracy = 90.740%
# Epoch: 12, Mini-Batches Completed: 800, Loss: 0.521, Test Accuracy = 90.770%
# Epoch: 12, Mini-Batches Completed: 900, Loss: 0.588, Test Accuracy = 90.500%
# Epoch: 12, Mini-Batches Completed: 1000, Loss: 0.586, Test Accuracy = 90.370%
# Epoch: 12, Mini-Batches Completed: 1100, Loss: 0.563, Test Accuracy = 90.320%
# Epoch: 12, Mini-Batches Completed: 1200, Loss: 0.541, Test Accuracy = 90.290%
# Epoch: 12, Mini-Batches Completed: 1300, Loss: 0.571, Test Accuracy = 90.020%
# Epoch: 12, Mini-Batches Completed: 1400, Loss: 0.574, Test Accuracy = 90.310%
# Epoch: 12, Mini-Batches Completed: 1500, Loss: 0.568, Test Accuracy = 90.530%
# Epoch: 12, Mini-Batches Completed: 1600, Loss: 0.562, Test Accuracy = 90.650%
# Epoch: 12, Mini-Batches Completed: 1700, Loss: 0.535, Test Accuracy = 90.080%
# Epoch: 12, Mini-Batches Completed: 1800, Loss: 0.580, Test Accuracy = 90.770%
# Starting Epoch: 13...
# Epoch: 13, Mini-Batches Completed: 100, Loss: 0.574, Test Accuracy = 90.130%
# Epoch: 13, Mini-Batches Completed: 200, Loss: 0.584, Test Accuracy = 90.490%
# Epoch: 13, Mini-Batches Completed: 300, Loss: 0.531, Test Accuracy = 90.550%
# Epoch: 13, Mini-Batches Completed: 400, Loss: 0.561, Test Accuracy = 89.720%
# Epoch: 13, Mini-Batches Completed: 500, Loss: 0.571, Test Accuracy = 89.700%
# Epoch: 13, Mini-Batches Completed: 600, Loss: 0.494, Test Accuracy = 90.070%
# Epoch: 13, Mini-Batches Completed: 700, Loss: 0.572, Test Accuracy = 90.020%
# Epoch: 13, Mini-Batches Completed: 800, Loss: 0.521, Test Accuracy = 89.940%
# Epoch: 13, Mini-Batches Completed: 900, Loss: 0.549, Test Accuracy = 90.450%
# Epoch: 13, Mini-Batches Completed: 1000, Loss: 0.587, Test Accuracy = 90.460%
# Epoch: 13, Mini-Batches Completed: 1100, Loss: 0.544, Test Accuracy = 90.540%
# Epoch: 13, Mini-Batches Completed: 1200, Loss: 0.535, Test Accuracy = 90.700%
# Epoch: 13, Mini-Batches Completed: 1300, Loss: 0.565, Test Accuracy = 90.060%
# Epoch: 13, Mini-Batches Completed: 1400, Loss: 0.548, Test Accuracy = 90.730%
# Epoch: 13, Mini-Batches Completed: 1500, Loss: 0.587, Test Accuracy = 90.780%
# Epoch: 13, Mini-Batches Completed: 1600, Loss: 0.537, Test Accuracy = 90.540%
# Epoch: 13, Mini-Batches Completed: 1700, Loss: 0.541, Test Accuracy = 90.600%
# Epoch: 13, Mini-Batches Completed: 1800, Loss: 0.544, Test Accuracy = 90.240%
# Starting Epoch: 14...
# Epoch: 14, Mini-Batches Completed: 100, Loss: 0.604, Test Accuracy = 90.830%
# Epoch: 14, Mini-Batches Completed: 200, Loss: 0.525, Test Accuracy = 90.660%
# Epoch: 14, Mini-Batches Completed: 300, Loss: 0.548, Test Accuracy = 90.130%
# Epoch: 14, Mini-Batches Completed: 400, Loss: 0.549, Test Accuracy = 90.510%
# Epoch: 14, Mini-Batches Completed: 500, Loss: 0.540, Test Accuracy = 90.640%
# Epoch: 14, Mini-Batches Completed: 600, Loss: 0.530, Test Accuracy = 90.300%
# Epoch: 14, Mini-Batches Completed: 700, Loss: 0.564, Test Accuracy = 90.130%
# Epoch: 14, Mini-Batches Completed: 800, Loss: 0.521, Test Accuracy = 90.160%
# Epoch: 14, Mini-Batches Completed: 900, Loss: 0.499, Test Accuracy = 90.720%
# Epoch: 14, Mini-Batches Completed: 1000, Loss: 0.542, Test Accuracy = 90.820%
# Epoch: 14, Mini-Batches Completed: 1100, Loss: 0.527, Test Accuracy = 89.780%
# Epoch: 14, Mini-Batches Completed: 1200, Loss: 0.537, Test Accuracy = 91.190%
# Epoch: 14, Mini-Batches Completed: 1300, Loss: 0.530, Test Accuracy = 91.010%
# Epoch: 14, Mini-Batches Completed: 1400, Loss: 0.545, Test Accuracy = 90.300%
# Epoch: 14, Mini-Batches Completed: 1500, Loss: 0.530, Test Accuracy = 90.360%
# Epoch: 14, Mini-Batches Completed: 1600, Loss: 0.556, Test Accuracy = 90.670%
# Epoch: 14, Mini-Batches Completed: 1700, Loss: 0.572, Test Accuracy = 91.280%
# Epoch: 14, Mini-Batches Completed: 1800, Loss: 0.544, Test Accuracy = 90.050%
# Starting Epoch: 15...
# Epoch: 15, Mini-Batches Completed: 100, Loss: 0.547, Test Accuracy = 90.590%
# Epoch: 15, Mini-Batches Completed: 200, Loss: 0.469, Test Accuracy = 90.090%
# Epoch: 15, Mini-Batches Completed: 300, Loss: 0.523, Test Accuracy = 90.870%
# Epoch: 15, Mini-Batches Completed: 400, Loss: 0.513, Test Accuracy = 91.030%
# Epoch: 15, Mini-Batches Completed: 500, Loss: 0.546, Test Accuracy = 89.890%
# Epoch: 15, Mini-Batches Completed: 600, Loss: 0.541, Test Accuracy = 90.760%
# Epoch: 15, Mini-Batches Completed: 700, Loss: 0.490, Test Accuracy = 90.400%
# Epoch: 15, Mini-Batches Completed: 800, Loss: 0.534, Test Accuracy = 89.790%
# Epoch: 15, Mini-Batches Completed: 900, Loss: 0.517, Test Accuracy = 90.510%
# Epoch: 15, Mini-Batches Completed: 1000, Loss: 0.543, Test Accuracy = 90.010%
# Epoch: 15, Mini-Batches Completed: 1100, Loss: 0.537, Test Accuracy = 90.990%
# Epoch: 15, Mini-Batches Completed: 1200, Loss: 0.502, Test Accuracy = 91.020%
# Epoch: 15, Mini-Batches Completed: 1300, Loss: 0.538, Test Accuracy = 90.540%
# Epoch: 15, Mini-Batches Completed: 1400, Loss: 0.582, Test Accuracy = 90.920%
# Epoch: 15, Mini-Batches Completed: 1500, Loss: 0.511, Test Accuracy = 89.940%
# Epoch: 15, Mini-Batches Completed: 1600, Loss: 0.521, Test Accuracy = 90.950%
# Epoch: 15, Mini-Batches Completed: 1700, Loss: 0.527, Test Accuracy = 90.120%
# Epoch: 15, Mini-Batches Completed: 1800, Loss: 0.507, Test Accuracy = 90.700%
# Finished Training

# %% [markdown]
# ### **Training Plots**

# %%
import matplotlib.pyplot as plt

# To create a plot with secondary y-axis we need to create a subplot
fig, ax1 = plt.subplots()

# Set title and x-axis label rotation
plt.title("Accuracy & Loss vs Epoch Mini-Batches")
plt.xticks(rotation=45)

# We use twinx to create a plot a secondary y axis
ax2 = ax1.twinx()

# Create plot for loss_log and accuracy_log
ax1.plot(epoch_log, loss_log, 'g-')
ax2.plot(epoch_log, accuracy_log, 'b-')

# Set labels
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color='g')
ax2.set_ylabel('Test Accuracy', color='b')

plt.show()
