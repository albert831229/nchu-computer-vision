# %% [markdown]
# # **Regularisation in PyTorch - Part 1**
# ### **First we train a CNN on the Fashion-MNIST Dataset usng NO Regularisation Methods**
#
# ---
#
#
# In this lesson, we first learn to create a **simple Convolutional Neural Network model** in PyTorch and train it to **classify images in the Fashion-MNIST Dataset**, without the use of any regularisation methods.
# 1. Import PyTorch libraries, define our Transformers, Load our dataset and Visualize our images.
# 2. Build a Simple CNN without Regularisation
# 3. Train Our CNN
# 3. Take a look at Data Augmentation

# %% [markdown]
# # **Import PyTorch libraries, Define Transfomers and Load & Visualise Dataset**

# %%
# Import PyTorch
import torch
import PIL

# We use torchvision to get our dataset and useful image transformations
import torchvision
import torchvision.transforms as transforms

# Import PyTorch's optimization libary and nn
# nn is used as the basic building block for our Network graphs
import torch.optim as optim
import torch.nn as nn

# Are we using our GPU?
print("GPU available: {}".format(torch.cuda.is_available()))
device = 'cuda' #'cpu' if no GPU available
# Out:
# GPU available: True

# %% [markdown]
# ### **Our Data Transform**

# %%
# Transform to a PyTorch tensors and the normalize our valeus between -1 and +1
transform = transforms.Compose([transforms.ToTensor(),
                               transforms.Normalize((0.5, ), (0.5, )) ])

# %%
# Load our Training Data and specify what transform to use when loading
trainset = torchvision.datasets.FashionMNIST(root='./data', train=True,
                                        download=True, transform=transform)

# Load our Test Data and specify what transform to use when loading
testset = torchvision.datasets.FashionMNIST(root='./data', train=False,
                                       download=True, transform=transform)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:00<00:00, 121683739.33it/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 98406106.96it/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:00<00:00, 65441548.88it/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<00:00, 19882391.34it/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw

# %%
# Prepare train and test loader
trainloader = torch.utils.data.DataLoader(trainset, batch_size=32,
                                          shuffle=True)

testloader = torch.utils.data.DataLoader(testset, batch_size=32,
                                         shuffle=False)

# Create a list with our class names
classes = ('T-shirt/top', 'Trouser', 'Pullover', 'Dress',
           'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot')

# %%
# We have 60,000 Image samples for our training data & 10,000 for our test data
# each 28 x 28 pixels, as they are grayscale, there is no 3rd dimension to our image
print(trainset.data.shape)
print(testset.data.shape)
# Out:
# torch.Size([60000, 28, 28])
# torch.Size([10000, 28, 28])

# %% [markdown]
# # **2. Building and Training Our Simple CNN with No Regularisation**
#
# #### **Defining Our Model**

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3)
        self.conv2 = nn.Conv2d(32, 64, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 12 * 12, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 64 * 12 * 12)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x


net = Net()
net.to(device)
# Out:
# Net(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=9216, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )

# %% [markdown]
# #### **Defining our Loss and Optimisation Functions**

# %%
# We import our optimizer function
import torch.optim as optim

# We use Cross Entropy Loss as our loss function
criterion = nn.CrossEntropyLoss()

# For our gradient descent algorthim or Optimizer
# We use Stochastic Gradient Descent (SGD) with a learning rate of 0.001
# We set the momentum to be 0.9
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %% [markdown]
# # **3. Training Our Model**

# %%
# We loop over the traing dataset multiple times (each time is called an epoch)
epochs = 15

# Create some empty arrays to store logs
epoch_log = []
loss_log = []
accuracy_log = []

# Iterate for a specified number of epochs
for epoch in range(epochs):
    print(f'Starting Epoch: {epoch+1}...')

    # We keep adding or accumulating our loss after each mini-batch in running_loss
    running_loss = 0.0

    # We iterate through our trainloader iterator
    # Each cycle is a minibatch
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # Move our data to GPU
        inputs = inputs.to(device)
        labels = labels.to(device)

        # Clear the gradients before training by setting to zero
        # Required for a fresh start
        optimizer.zero_grad()

        # Forward -> backprop + optimize
        outputs = net(inputs) # Forward Propagation
        loss = criterion(outputs, labels) # Get Loss (quantify the difference between the results and predictions)
        loss.backward() # Back propagate to obtain the new gradients for all nodes
        optimizer.step() # Update the gradients/weights

        # Print Training statistics - Epoch/Iterations/Loss/Accurachy
        running_loss += loss.item()
        if i % 100 == 99:    # show our loss every 50 mini-batches
            correct = 0 # Initialize our variable to hold the count for the correct predictions
            total = 0 # Initialize our variable to hold the count of the number of labels iterated

            # We don't need gradients for validation, so wrap in
            # no_grad to save memory
            with torch.no_grad():
                # Iterate through the testloader iterator
                for data in testloader:
                    images, labels = data
                    # Move our data to GPU
                    images = images.to(device)
                    labels = labels.to(device)

                    # Foward propagate our test data batch through our model
                    outputs = net(images)

                     # Get predictions from the maximum value
                    _, predicted = torch.max(outputs.data, 1)
                    # Keep adding the label size or length to the total variable
                    total += labels.size(0)
                    # Keep a running total of the number of predictions predicted correctly
                    correct += (predicted == labels).sum().item()

                accuracy = 100 * correct / total
                epoch_num = epoch + 1
                actual_loss = running_loss / 50
                print(f'Epoch: {epoch_num}, Mini-Batches Completed: {(i+1)}, Loss: {actual_loss:.3f}, Test Accuracy = {accuracy:.3f}%')
                running_loss = 0.0

    # Store training stats after each epoch
    epoch_log.append(epoch_num)
    loss_log.append(actual_loss)
    accuracy_log.append(accuracy)

print('Finished Training')
# Out:
# Starting Epoch: 1...
# Epoch: 1, Mini-Batches Completed: 100, Loss: 3.769, Test Accuracy = 61.560%
# Epoch: 1, Mini-Batches Completed: 200, Loss: 1.690, Test Accuracy = 73.000%
# Epoch: 1, Mini-Batches Completed: 300, Loss: 1.443, Test Accuracy = 72.940%
# Epoch: 1, Mini-Batches Completed: 400, Loss: 1.337, Test Accuracy = 75.920%
# Epoch: 1, Mini-Batches Completed: 500, Loss: 1.285, Test Accuracy = 71.800%
# Epoch: 1, Mini-Batches Completed: 600, Loss: 1.238, Test Accuracy = 76.530%
# Epoch: 1, Mini-Batches Completed: 700, Loss: 1.204, Test Accuracy = 75.650%
# Epoch: 1, Mini-Batches Completed: 800, Loss: 1.162, Test Accuracy = 76.280%
# Epoch: 1, Mini-Batches Completed: 900, Loss: 1.142, Test Accuracy = 76.280%
# Epoch: 1, Mini-Batches Completed: 1000, Loss: 1.107, Test Accuracy = 77.320%
# Epoch: 1, Mini-Batches Completed: 1100, Loss: 1.105, Test Accuracy = 79.760%
# Epoch: 1, Mini-Batches Completed: 1200, Loss: 1.137, Test Accuracy = 78.810%
# Epoch: 1, Mini-Batches Completed: 1300, Loss: 1.047, Test Accuracy = 81.110%
# Epoch: 1, Mini-Batches Completed: 1400, Loss: 1.006, Test Accuracy = 80.690%
# Epoch: 1, Mini-Batches Completed: 1500, Loss: 1.000, Test Accuracy = 81.040%
# Epoch: 1, Mini-Batches Completed: 1600, Loss: 0.992, Test Accuracy = 82.180%
# Epoch: 1, Mini-Batches Completed: 1700, Loss: 0.934, Test Accuracy = 81.150%
# Epoch: 1, Mini-Batches Completed: 1800, Loss: 0.916, Test Accuracy = 82.620%
# Starting Epoch: 2...
# Epoch: 2, Mini-Batches Completed: 100, Loss: 0.929, Test Accuracy = 81.900%
# Epoch: 2, Mini-Batches Completed: 200, Loss: 0.865, Test Accuracy = 82.860%
# Epoch: 2, Mini-Batches Completed: 300, Loss: 0.888, Test Accuracy = 82.940%
# Epoch: 2, Mini-Batches Completed: 400, Loss: 0.881, Test Accuracy = 82.010%
# Epoch: 2, Mini-Batches Completed: 500, Loss: 0.907, Test Accuracy = 83.750%
# Epoch: 2, Mini-Batches Completed: 600, Loss: 0.897, Test Accuracy = 81.160%
# Epoch: 2, Mini-Batches Completed: 700, Loss: 0.887, Test Accuracy = 83.240%
# Epoch: 2, Mini-Batches Completed: 800, Loss: 0.889, Test Accuracy = 82.790%
# Epoch: 2, Mini-Batches Completed: 900, Loss: 0.809, Test Accuracy = 84.210%
# Epoch: 2, Mini-Batches Completed: 1000, Loss: 0.858, Test Accuracy = 84.520%
# Epoch: 2, Mini-Batches Completed: 1100, Loss: 0.836, Test Accuracy = 84.420%
# Epoch: 2, Mini-Batches Completed: 1200, Loss: 0.816, Test Accuracy = 84.010%
# Epoch: 2, Mini-Batches Completed: 1300, Loss: 0.803, Test Accuracy = 84.900%
# Epoch: 2, Mini-Batches Completed: 1400, Loss: 0.809, Test Accuracy = 85.170%
# Epoch: 2, Mini-Batches Completed: 1500, Loss: 0.804, Test Accuracy = 84.280%
# Epoch: 2, Mini-Batches Completed: 1600, Loss: 0.792, Test Accuracy = 85.270%
# Epoch: 2, Mini-Batches Completed: 1700, Loss: 0.755, Test Accuracy = 85.430%
# Epoch: 2, Mini-Batches Completed: 1800, Loss: 0.777, Test Accuracy = 85.860%
# Starting Epoch: 3...
# Epoch: 3, Mini-Batches Completed: 100, Loss: 0.689, Test Accuracy = 85.710%
# Epoch: 3, Mini-Batches Completed: 200, Loss: 0.795, Test Accuracy = 85.380%
# Epoch: 3, Mini-Batches Completed: 300, Loss: 0.740, Test Accuracy = 85.790%
# Epoch: 3, Mini-Batches Completed: 400, Loss: 0.719, Test Accuracy = 84.540%
# Epoch: 3, Mini-Batches Completed: 500, Loss: 0.720, Test Accuracy = 84.740%
# Epoch: 3, Mini-Batches Completed: 600, Loss: 0.753, Test Accuracy = 85.500%
# Epoch: 3, Mini-Batches Completed: 700, Loss: 0.781, Test Accuracy = 85.180%
# Epoch: 3, Mini-Batches Completed: 800, Loss: 0.741, Test Accuracy = 85.920%
# Epoch: 3, Mini-Batches Completed: 900, Loss: 0.713, Test Accuracy = 86.900%
# Epoch: 3, Mini-Batches Completed: 1000, Loss: 0.730, Test Accuracy = 86.480%
# Epoch: 3, Mini-Batches Completed: 1100, Loss: 0.700, Test Accuracy = 86.800%
# Epoch: 3, Mini-Batches Completed: 1200, Loss: 0.728, Test Accuracy = 86.850%
# Epoch: 3, Mini-Batches Completed: 1300, Loss: 0.695, Test Accuracy = 86.630%
# Epoch: 3, Mini-Batches Completed: 1400, Loss: 0.688, Test Accuracy = 86.950%
# Epoch: 3, Mini-Batches Completed: 1500, Loss: 0.673, Test Accuracy = 87.060%
# Epoch: 3, Mini-Batches Completed: 1600, Loss: 0.674, Test Accuracy = 87.300%
# Epoch: 3, Mini-Batches Completed: 1700, Loss: 0.664, Test Accuracy = 86.440%
# Epoch: 3, Mini-Batches Completed: 1800, Loss: 0.663, Test Accuracy = 87.280%
# Starting Epoch: 4...
# Epoch: 4, Mini-Batches Completed: 100, Loss: 0.683, Test Accuracy = 87.890%
# Epoch: 4, Mini-Batches Completed: 200, Loss: 0.651, Test Accuracy = 86.410%
# Epoch: 4, Mini-Batches Completed: 300, Loss: 0.665, Test Accuracy = 86.700%
# Epoch: 4, Mini-Batches Completed: 400, Loss: 0.661, Test Accuracy = 87.300%
# Epoch: 4, Mini-Batches Completed: 500, Loss: 0.614, Test Accuracy = 87.560%
# Epoch: 4, Mini-Batches Completed: 600, Loss: 0.684, Test Accuracy = 87.100%
# Epoch: 4, Mini-Batches Completed: 700, Loss: 0.617, Test Accuracy = 87.760%
# Epoch: 4, Mini-Batches Completed: 800, Loss: 0.628, Test Accuracy = 88.030%
# Epoch: 4, Mini-Batches Completed: 900, Loss: 0.617, Test Accuracy = 86.210%
# Epoch: 4, Mini-Batches Completed: 1000, Loss: 0.634, Test Accuracy = 88.060%
# Epoch: 4, Mini-Batches Completed: 1100, Loss: 0.634, Test Accuracy = 88.270%
# Epoch: 4, Mini-Batches Completed: 1200, Loss: 0.657, Test Accuracy = 87.600%
# Epoch: 4, Mini-Batches Completed: 1300, Loss: 0.626, Test Accuracy = 87.980%
# Epoch: 4, Mini-Batches Completed: 1400, Loss: 0.610, Test Accuracy = 88.220%
# Epoch: 4, Mini-Batches Completed: 1500, Loss: 0.647, Test Accuracy = 87.790%
# Epoch: 4, Mini-Batches Completed: 1600, Loss: 0.672, Test Accuracy = 88.550%
# Epoch: 4, Mini-Batches Completed: 1700, Loss: 0.588, Test Accuracy = 88.040%
# Epoch: 4, Mini-Batches Completed: 1800, Loss: 0.595, Test Accuracy = 87.760%
# Starting Epoch: 5...
# Epoch: 5, Mini-Batches Completed: 100, Loss: 0.578, Test Accuracy = 87.840%
# Epoch: 5, Mini-Batches Completed: 200, Loss: 0.602, Test Accuracy = 88.490%
# Epoch: 5, Mini-Batches Completed: 300, Loss: 0.586, Test Accuracy = 88.340%
# Epoch: 5, Mini-Batches Completed: 400, Loss: 0.554, Test Accuracy = 88.010%
# Epoch: 5, Mini-Batches Completed: 500, Loss: 0.591, Test Accuracy = 88.560%
# Epoch: 5, Mini-Batches Completed: 600, Loss: 0.555, Test Accuracy = 88.260%
# Epoch: 5, Mini-Batches Completed: 700, Loss: 0.578, Test Accuracy = 88.330%
# Epoch: 5, Mini-Batches Completed: 800, Loss: 0.628, Test Accuracy = 87.720%
# Epoch: 5, Mini-Batches Completed: 900, Loss: 0.582, Test Accuracy = 88.920%
# Epoch: 5, Mini-Batches Completed: 1000, Loss: 0.545, Test Accuracy = 88.580%
# Epoch: 5, Mini-Batches Completed: 1100, Loss: 0.596, Test Accuracy = 88.260%
# Epoch: 5, Mini-Batches Completed: 1200, Loss: 0.614, Test Accuracy = 88.500%
# Epoch: 5, Mini-Batches Completed: 1300, Loss: 0.586, Test Accuracy = 88.090%
# Epoch: 5, Mini-Batches Completed: 1400, Loss: 0.583, Test Accuracy = 87.960%
# Epoch: 5, Mini-Batches Completed: 1500, Loss: 0.529, Test Accuracy = 88.260%
# Epoch: 5, Mini-Batches Completed: 1600, Loss: 0.568, Test Accuracy = 89.040%
# Epoch: 5, Mini-Batches Completed: 1700, Loss: 0.587, Test Accuracy = 87.900%
# Epoch: 5, Mini-Batches Completed: 1800, Loss: 0.607, Test Accuracy = 88.930%
# Starting Epoch: 6...
# Epoch: 6, Mini-Batches Completed: 100, Loss: 0.524, Test Accuracy = 88.960%
# Epoch: 6, Mini-Batches Completed: 200, Loss: 0.526, Test Accuracy = 88.830%
# Epoch: 6, Mini-Batches Completed: 300, Loss: 0.552, Test Accuracy = 88.270%
# Epoch: 6, Mini-Batches Completed: 400, Loss: 0.551, Test Accuracy = 89.070%
# Epoch: 6, Mini-Batches Completed: 500, Loss: 0.560, Test Accuracy = 89.310%
# Epoch: 6, Mini-Batches Completed: 600, Loss: 0.525, Test Accuracy = 89.210%
# Epoch: 6, Mini-Batches Completed: 700, Loss: 0.514, Test Accuracy = 88.420%
# Epoch: 6, Mini-Batches Completed: 800, Loss: 0.517, Test Accuracy = 88.750%
# Epoch: 6, Mini-Batches Completed: 900, Loss: 0.508, Test Accuracy = 88.550%
# Epoch: 6, Mini-Batches Completed: 1000, Loss: 0.569, Test Accuracy = 89.290%
# Epoch: 6, Mini-Batches Completed: 1100, Loss: 0.497, Test Accuracy = 89.050%
# Epoch: 6, Mini-Batches Completed: 1200, Loss: 0.626, Test Accuracy = 89.310%
# Epoch: 6, Mini-Batches Completed: 1300, Loss: 0.547, Test Accuracy = 89.420%
# Epoch: 6, Mini-Batches Completed: 1400, Loss: 0.514, Test Accuracy = 89.460%
# Epoch: 6, Mini-Batches Completed: 1500, Loss: 0.550, Test Accuracy = 89.710%
# Epoch: 6, Mini-Batches Completed: 1600, Loss: 0.545, Test Accuracy = 89.060%
# Epoch: 6, Mini-Batches Completed: 1700, Loss: 0.550, Test Accuracy = 89.370%
# Epoch: 6, Mini-Batches Completed: 1800, Loss: 0.517, Test Accuracy = 89.670%
# Starting Epoch: 7...
# Epoch: 7, Mini-Batches Completed: 100, Loss: 0.515, Test Accuracy = 89.330%
# Epoch: 7, Mini-Batches Completed: 200, Loss: 0.447, Test Accuracy = 89.160%
# Epoch: 7, Mini-Batches Completed: 300, Loss: 0.519, Test Accuracy = 89.470%
# Epoch: 7, Mini-Batches Completed: 400, Loss: 0.537, Test Accuracy = 89.160%
# Epoch: 7, Mini-Batches Completed: 500, Loss: 0.538, Test Accuracy = 89.230%
# Epoch: 7, Mini-Batches Completed: 600, Loss: 0.512, Test Accuracy = 89.090%
# Epoch: 7, Mini-Batches Completed: 700, Loss: 0.477, Test Accuracy = 89.610%
# Epoch: 7, Mini-Batches Completed: 800, Loss: 0.489, Test Accuracy = 89.050%
# Epoch: 7, Mini-Batches Completed: 900, Loss: 0.545, Test Accuracy = 89.650%
# Epoch: 7, Mini-Batches Completed: 1000, Loss: 0.486, Test Accuracy = 89.350%
# Epoch: 7, Mini-Batches Completed: 1100, Loss: 0.511, Test Accuracy = 89.710%
# Epoch: 7, Mini-Batches Completed: 1200, Loss: 0.501, Test Accuracy = 89.650%
# Epoch: 7, Mini-Batches Completed: 1300, Loss: 0.507, Test Accuracy = 89.470%
# Epoch: 7, Mini-Batches Completed: 1400, Loss: 0.498, Test Accuracy = 89.240%
# Epoch: 7, Mini-Batches Completed: 1500, Loss: 0.487, Test Accuracy = 89.470%
# Epoch: 7, Mini-Batches Completed: 1600, Loss: 0.488, Test Accuracy = 89.950%
# Epoch: 7, Mini-Batches Completed: 1700, Loss: 0.476, Test Accuracy = 88.760%
# Epoch: 7, Mini-Batches Completed: 1800, Loss: 0.492, Test Accuracy = 89.800%
# Starting Epoch: 8...
# Epoch: 8, Mini-Batches Completed: 100, Loss: 0.494, Test Accuracy = 90.080%
# Epoch: 8, Mini-Batches Completed: 200, Loss: 0.441, Test Accuracy = 90.130%
# Epoch: 8, Mini-Batches Completed: 300, Loss: 0.479, Test Accuracy = 90.070%
# Epoch: 8, Mini-Batches Completed: 400, Loss: 0.454, Test Accuracy = 89.090%
# Epoch: 8, Mini-Batches Completed: 500, Loss: 0.484, Test Accuracy = 89.220%
# Epoch: 8, Mini-Batches Completed: 600, Loss: 0.481, Test Accuracy = 89.590%
# Epoch: 8, Mini-Batches Completed: 700, Loss: 0.459, Test Accuracy = 89.660%
# Epoch: 8, Mini-Batches Completed: 800, Loss: 0.503, Test Accuracy = 88.740%
# Epoch: 8, Mini-Batches Completed: 900, Loss: 0.460, Test Accuracy = 90.220%
# Epoch: 8, Mini-Batches Completed: 1000, Loss: 0.478, Test Accuracy = 89.850%
# Epoch: 8, Mini-Batches Completed: 1100, Loss: 0.511, Test Accuracy = 89.390%
# Epoch: 8, Mini-Batches Completed: 1200, Loss: 0.461, Test Accuracy = 88.380%
# Epoch: 8, Mini-Batches Completed: 1300, Loss: 0.471, Test Accuracy = 90.110%
# Epoch: 8, Mini-Batches Completed: 1400, Loss: 0.447, Test Accuracy = 90.290%
# Epoch: 8, Mini-Batches Completed: 1500, Loss: 0.473, Test Accuracy = 90.190%
# Epoch: 8, Mini-Batches Completed: 1600, Loss: 0.485, Test Accuracy = 89.810%
# Epoch: 8, Mini-Batches Completed: 1700, Loss: 0.478, Test Accuracy = 89.550%
# Epoch: 8, Mini-Batches Completed: 1800, Loss: 0.460, Test Accuracy = 89.940%
# Starting Epoch: 9...
# Epoch: 9, Mini-Batches Completed: 100, Loss: 0.471, Test Accuracy = 89.830%
# Epoch: 9, Mini-Batches Completed: 200, Loss: 0.449, Test Accuracy = 89.920%
# Epoch: 9, Mini-Batches Completed: 300, Loss: 0.439, Test Accuracy = 90.150%
# Epoch: 9, Mini-Batches Completed: 400, Loss: 0.452, Test Accuracy = 90.380%
# Epoch: 9, Mini-Batches Completed: 500, Loss: 0.457, Test Accuracy = 89.920%
# Epoch: 9, Mini-Batches Completed: 600, Loss: 0.456, Test Accuracy = 90.060%
# Epoch: 9, Mini-Batches Completed: 700, Loss: 0.429, Test Accuracy = 89.650%
# Epoch: 9, Mini-Batches Completed: 800, Loss: 0.432, Test Accuracy = 90.090%
# Epoch: 9, Mini-Batches Completed: 900, Loss: 0.419, Test Accuracy = 89.770%
# Epoch: 9, Mini-Batches Completed: 1000, Loss: 0.416, Test Accuracy = 89.880%
# Epoch: 9, Mini-Batches Completed: 1100, Loss: 0.477, Test Accuracy = 90.110%
# Epoch: 9, Mini-Batches Completed: 1200, Loss: 0.449, Test Accuracy = 89.890%
# Epoch: 9, Mini-Batches Completed: 1300, Loss: 0.446, Test Accuracy = 90.350%
# Epoch: 9, Mini-Batches Completed: 1400, Loss: 0.462, Test Accuracy = 90.310%
# Epoch: 9, Mini-Batches Completed: 1500, Loss: 0.454, Test Accuracy = 88.520%
# Epoch: 9, Mini-Batches Completed: 1600, Loss: 0.465, Test Accuracy = 89.740%
# Epoch: 9, Mini-Batches Completed: 1700, Loss: 0.425, Test Accuracy = 89.940%
# Epoch: 9, Mini-Batches Completed: 1800, Loss: 0.433, Test Accuracy = 90.430%
# Starting Epoch: 10...
# Epoch: 10, Mini-Batches Completed: 100, Loss: 0.413, Test Accuracy = 90.130%
# Epoch: 10, Mini-Batches Completed: 200, Loss: 0.425, Test Accuracy = 90.160%
# Epoch: 10, Mini-Batches Completed: 300, Loss: 0.440, Test Accuracy = 88.840%
# Epoch: 10, Mini-Batches Completed: 400, Loss: 0.434, Test Accuracy = 90.030%
# Epoch: 10, Mini-Batches Completed: 500, Loss: 0.419, Test Accuracy = 90.270%
# Epoch: 10, Mini-Batches Completed: 600, Loss: 0.445, Test Accuracy = 90.160%
# Epoch: 10, Mini-Batches Completed: 700, Loss: 0.430, Test Accuracy = 90.540%
# Epoch: 10, Mini-Batches Completed: 800, Loss: 0.417, Test Accuracy = 90.520%
# Epoch: 10, Mini-Batches Completed: 900, Loss: 0.425, Test Accuracy = 89.970%
# Epoch: 10, Mini-Batches Completed: 1000, Loss: 0.413, Test Accuracy = 90.040%
# Epoch: 10, Mini-Batches Completed: 1100, Loss: 0.450, Test Accuracy = 89.910%
# Epoch: 10, Mini-Batches Completed: 1200, Loss: 0.417, Test Accuracy = 90.800%
# Epoch: 10, Mini-Batches Completed: 1300, Loss: 0.381, Test Accuracy = 90.260%
# Epoch: 10, Mini-Batches Completed: 1400, Loss: 0.430, Test Accuracy = 90.570%
# Epoch: 10, Mini-Batches Completed: 1500, Loss: 0.394, Test Accuracy = 90.860%
# Epoch: 10, Mini-Batches Completed: 1600, Loss: 0.462, Test Accuracy = 90.470%
# Epoch: 10, Mini-Batches Completed: 1700, Loss: 0.390, Test Accuracy = 90.560%
# Epoch: 10, Mini-Batches Completed: 1800, Loss: 0.419, Test Accuracy = 90.130%
# Starting Epoch: 11...
# Epoch: 11, Mini-Batches Completed: 100, Loss: 0.418, Test Accuracy = 90.710%
# Epoch: 11, Mini-Batches Completed: 200, Loss: 0.389, Test Accuracy = 90.020%
# Epoch: 11, Mini-Batches Completed: 300, Loss: 0.429, Test Accuracy = 90.800%
# Epoch: 11, Mini-Batches Completed: 400, Loss: 0.382, Test Accuracy = 89.940%
# Epoch: 11, Mini-Batches Completed: 500, Loss: 0.393, Test Accuracy = 90.550%
# Epoch: 11, Mini-Batches Completed: 600, Loss: 0.400, Test Accuracy = 90.570%
# Epoch: 11, Mini-Batches Completed: 700, Loss: 0.371, Test Accuracy = 90.540%
# Epoch: 11, Mini-Batches Completed: 800, Loss: 0.443, Test Accuracy = 90.670%
# Epoch: 11, Mini-Batches Completed: 900, Loss: 0.441, Test Accuracy = 90.410%
# Epoch: 11, Mini-Batches Completed: 1000, Loss: 0.391, Test Accuracy = 89.140%
# Epoch: 11, Mini-Batches Completed: 1100, Loss: 0.382, Test Accuracy = 91.050%
# Epoch: 11, Mini-Batches Completed: 1200, Loss: 0.365, Test Accuracy = 90.410%
# Epoch: 11, Mini-Batches Completed: 1300, Loss: 0.423, Test Accuracy = 90.980%
# Epoch: 11, Mini-Batches Completed: 1400, Loss: 0.383, Test Accuracy = 90.600%
# Epoch: 11, Mini-Batches Completed: 1500, Loss: 0.389, Test Accuracy = 90.780%
# Epoch: 11, Mini-Batches Completed: 1600, Loss: 0.385, Test Accuracy = 90.840%
# Epoch: 11, Mini-Batches Completed: 1700, Loss: 0.401, Test Accuracy = 90.030%
# Epoch: 11, Mini-Batches Completed: 1800, Loss: 0.401, Test Accuracy = 90.650%
# Starting Epoch: 12...
# Epoch: 12, Mini-Batches Completed: 100, Loss: 0.355, Test Accuracy = 90.870%
# Epoch: 12, Mini-Batches Completed: 200, Loss: 0.401, Test Accuracy = 90.730%
# Epoch: 12, Mini-Batches Completed: 300, Loss: 0.396, Test Accuracy = 90.760%
# Epoch: 12, Mini-Batches Completed: 400, Loss: 0.357, Test Accuracy = 90.650%
# Epoch: 12, Mini-Batches Completed: 500, Loss: 0.342, Test Accuracy = 89.840%
# Epoch: 12, Mini-Batches Completed: 600, Loss: 0.397, Test Accuracy = 90.700%
# Epoch: 12, Mini-Batches Completed: 700, Loss: 0.388, Test Accuracy = 90.950%
# Epoch: 12, Mini-Batches Completed: 800, Loss: 0.392, Test Accuracy = 90.750%
# Epoch: 12, Mini-Batches Completed: 900, Loss: 0.399, Test Accuracy = 90.950%
# Epoch: 12, Mini-Batches Completed: 1000, Loss: 0.375, Test Accuracy = 90.600%
# Epoch: 12, Mini-Batches Completed: 1100, Loss: 0.365, Test Accuracy = 90.800%
# Epoch: 12, Mini-Batches Completed: 1200, Loss: 0.391, Test Accuracy = 91.210%
# Epoch: 12, Mini-Batches Completed: 1300, Loss: 0.375, Test Accuracy = 90.730%
# Epoch: 12, Mini-Batches Completed: 1400, Loss: 0.373, Test Accuracy = 90.530%
# Epoch: 12, Mini-Batches Completed: 1500, Loss: 0.389, Test Accuracy = 90.510%
# Epoch: 12, Mini-Batches Completed: 1600, Loss: 0.330, Test Accuracy = 90.830%
# Epoch: 12, Mini-Batches Completed: 1700, Loss: 0.409, Test Accuracy = 90.970%
# Epoch: 12, Mini-Batches Completed: 1800, Loss: 0.366, Test Accuracy = 90.890%
# Starting Epoch: 13...
# Epoch: 13, Mini-Batches Completed: 100, Loss: 0.346, Test Accuracy = 90.570%
# Epoch: 13, Mini-Batches Completed: 200, Loss: 0.365, Test Accuracy = 90.980%
# Epoch: 13, Mini-Batches Completed: 300, Loss: 0.333, Test Accuracy = 90.910%
# Epoch: 13, Mini-Batches Completed: 400, Loss: 0.370, Test Accuracy = 90.750%
# Epoch: 13, Mini-Batches Completed: 500, Loss: 0.354, Test Accuracy = 91.090%
# Epoch: 13, Mini-Batches Completed: 600, Loss: 0.369, Test Accuracy = 91.010%
# Epoch: 13, Mini-Batches Completed: 700, Loss: 0.357, Test Accuracy = 90.920%
# Epoch: 13, Mini-Batches Completed: 800, Loss: 0.364, Test Accuracy = 90.510%
# Epoch: 13, Mini-Batches Completed: 900, Loss: 0.351, Test Accuracy = 90.880%
# Epoch: 13, Mini-Batches Completed: 1000, Loss: 0.387, Test Accuracy = 91.210%
# Epoch: 13, Mini-Batches Completed: 1100, Loss: 0.368, Test Accuracy = 90.910%
# Epoch: 13, Mini-Batches Completed: 1200, Loss: 0.361, Test Accuracy = 91.120%
# Epoch: 13, Mini-Batches Completed: 1300, Loss: 0.316, Test Accuracy = 91.190%
# Epoch: 13, Mini-Batches Completed: 1400, Loss: 0.353, Test Accuracy = 90.750%
# Epoch: 13, Mini-Batches Completed: 1500, Loss: 0.347, Test Accuracy = 91.120%
# Epoch: 13, Mini-Batches Completed: 1600, Loss: 0.374, Test Accuracy = 90.750%
# Epoch: 13, Mini-Batches Completed: 1700, Loss: 0.395, Test Accuracy = 90.820%
# Epoch: 13, Mini-Batches Completed: 1800, Loss: 0.321, Test Accuracy = 90.380%
# Starting Epoch: 14...
# Epoch: 14, Mini-Batches Completed: 100, Loss: 0.331, Test Accuracy = 90.640%
# Epoch: 14, Mini-Batches Completed: 200, Loss: 0.311, Test Accuracy = 90.960%
# Epoch: 14, Mini-Batches Completed: 300, Loss: 0.359, Test Accuracy = 91.180%
# Epoch: 14, Mini-Batches Completed: 400, Loss: 0.357, Test Accuracy = 90.750%
# Epoch: 14, Mini-Batches Completed: 500, Loss: 0.341, Test Accuracy = 91.060%
# Epoch: 14, Mini-Batches Completed: 600, Loss: 0.328, Test Accuracy = 91.180%
# Epoch: 14, Mini-Batches Completed: 700, Loss: 0.349, Test Accuracy = 91.210%
# Epoch: 14, Mini-Batches Completed: 800, Loss: 0.325, Test Accuracy = 91.050%
# Epoch: 14, Mini-Batches Completed: 900, Loss: 0.327, Test Accuracy = 91.170%
# Epoch: 14, Mini-Batches Completed: 1000, Loss: 0.344, Test Accuracy = 91.270%
# Epoch: 14, Mini-Batches Completed: 1100, Loss: 0.367, Test Accuracy = 90.910%
# Epoch: 14, Mini-Batches Completed: 1200, Loss: 0.345, Test Accuracy = 91.340%
# Epoch: 14, Mini-Batches Completed: 1300, Loss: 0.351, Test Accuracy = 91.320%
# Epoch: 14, Mini-Batches Completed: 1400, Loss: 0.291, Test Accuracy = 91.310%
# Epoch: 14, Mini-Batches Completed: 1500, Loss: 0.322, Test Accuracy = 91.450%
# Epoch: 14, Mini-Batches Completed: 1600, Loss: 0.337, Test Accuracy = 90.840%
# Epoch: 14, Mini-Batches Completed: 1700, Loss: 0.358, Test Accuracy = 90.910%
# Epoch: 14, Mini-Batches Completed: 1800, Loss: 0.358, Test Accuracy = 91.370%
# Starting Epoch: 15...
# Epoch: 15, Mini-Batches Completed: 100, Loss: 0.318, Test Accuracy = 91.090%
# Epoch: 15, Mini-Batches Completed: 200, Loss: 0.267, Test Accuracy = 91.450%
# Epoch: 15, Mini-Batches Completed: 300, Loss: 0.328, Test Accuracy = 91.260%
# Epoch: 15, Mini-Batches Completed: 400, Loss: 0.295, Test Accuracy = 91.450%
# Epoch: 15, Mini-Batches Completed: 500, Loss: 0.325, Test Accuracy = 90.610%
# Epoch: 15, Mini-Batches Completed: 600, Loss: 0.306, Test Accuracy = 91.130%
# Epoch: 15, Mini-Batches Completed: 700, Loss: 0.341, Test Accuracy = 91.240%
# Epoch: 15, Mini-Batches Completed: 800, Loss: 0.328, Test Accuracy = 91.280%
# Epoch: 15, Mini-Batches Completed: 900, Loss: 0.355, Test Accuracy = 91.280%
# Epoch: 15, Mini-Batches Completed: 1000, Loss: 0.319, Test Accuracy = 91.300%
# Epoch: 15, Mini-Batches Completed: 1100, Loss: 0.364, Test Accuracy = 91.260%
# Epoch: 15, Mini-Batches Completed: 1200, Loss: 0.319, Test Accuracy = 91.040%
# Epoch: 15, Mini-Batches Completed: 1300, Loss: 0.322, Test Accuracy = 91.210%
# Epoch: 15, Mini-Batches Completed: 1400, Loss: 0.326, Test Accuracy = 91.270%
# Epoch: 15, Mini-Batches Completed: 1500, Loss: 0.337, Test Accuracy = 91.020%
# Epoch: 15, Mini-Batches Completed: 1600, Loss: 0.309, Test Accuracy = 90.450%
# Epoch: 15, Mini-Batches Completed: 1700, Loss: 0.328, Test Accuracy = 91.050%
# Epoch: 15, Mini-Batches Completed: 1800, Loss: 0.320, Test Accuracy = 91.520%
# Finished Training

# %% [markdown]
# #### **Our Model's Accuracy**

# %%
correct = 0
total = 0

with torch.no_grad():
    for data in testloader:
        images, labels = data
        # Move our data to GPU
        images = images.to(device)
        labels = labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f'Accuracy of the network on the 10000 test images: {accuracy:.4}%')
# Out:
# Accuracy of the network on the 10000 test images: 91.29%

# %% [markdown]
# #### **Our Training Plots**

# %%
import matplotlib.pyplot as plt
# To create a plot with secondary y-axis we need to create a subplot
fig, ax1 = plt.subplots()

# Set title and x-axis label rotation
plt.title("Accuracy & Loss vs Epoch Mini-Batches")
plt.xticks(rotation=45)

# We use twinx to create a plot a secondary y axis
ax2 = ax1.twinx()

# Create plot for loss_log and accuracy_log
ax1.plot(epoch_log, loss_log, 'g-')
ax2.plot(epoch_log, accuracy_log, 'b-')

# Set labels
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color='g')
ax2.set_ylabel('Test Accuracy', color='b')

plt.show()

# %% [markdown]
# # **4. Data Augumentation**
#
# To introduce Data Augmentation to our training data we simply create new Transform functions.
#
# **Recall our previous transformation function**
#
# ```transform = transforms.Compose([transforms.ToTensor(),
#                                transforms.Normalize((0.5, ), (0.5, )) ])```
#
# ### **We are going to firstly demonstrate how Data Augmentation Affects Our Images**

# %%
# We import PIL, an Image Processing library to implement random rotations
import PIL

data_aug_transform = transforms.Compose([
        transforms.RandomAffine(degrees = 10, translate = (0.05,0.05), shear = 5),
        transforms.ColorJitter(hue = .05, saturation = .05),
        transforms.RandomHorizontalFlip(),
        transforms.Grayscale(num_output_channels = 1)
])

# %% [markdown]
# #### **Perform the Data Augmentatin on a Single Image using the function below to Visualize the effects**

# %%
from matplotlib.pyplot import figure, imshow, axis
from matplotlib.image import imread

def showAugmentations(image, augmentations = 6):
    fig = figure()
    for i in range(augmentations):
        a = fig.add_subplot(1,augmentations,i+1)
        img = data_aug_transform(image)
        imshow(img ,cmap='Greys_r')
        axis('off')

# %%
# Load the first Image from our training data as a numpy array
image = trainset.data[0].numpy()

# Convert it to PIL image's format
img_pil = PIL.Image.fromarray(image)

showAugmentations(img_pil, 8)
